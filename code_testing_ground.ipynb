# %%
import os

# %%
path="/home/nebiyu/Documents/github_repos"

# %%
for dir_path,dir_name,file_name in os.walk(path):
    print(file_nam)
# Out:
# ['llms_scratch', 'speech_reco_imp', 'my_tiny_reco', 'finetuning', 'kebi', 'full_stack_journey', 'TTS', 'work-projects']
# ['.git', 'notebooks']
# ['hooks', 'refs', 'logs', 'branches', 'info', 'objects']
# []
# ['heads', 'tags', 'remotes']
# []
# []
# ['origin']
# []
# ['refs']
# ['heads', 'remotes']
# []
# ['origin']
# []
# []
# []
# ['8d', 'e6', 'f6', 'aa', '88', '76', '2f', '9d', 'f4', '48', 'ed', 'da', '05', '85', '6b', 'bb', '81', '66', '4a', 'ef', '46', 'd1', '36', '01', '3f', 'b0', '4c', '7c', '95', 'd3', 'b8', 'a8', '16', '06', '86', 'db', 'd0', 'f0', '13', '0b', 'ba', 'e9', '37', 'f1', 'a1', '3a', 'be', '1f', '82', '24', '54', '84', '1a', '63', '44', '7a', 'ea', 'pack', 'ee', 'fb', 'e4', 'ca', 'ab', 'fd', '1e', '68', 'b1', 'd6', '19', '9b', 'eb', '33', '8e', 'a6', 'c9', '69', '89', '4d', 'fa', 'info', '97', '98', '5c', 'd8', '71', '17', '65', '3e', 'b4']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ...
